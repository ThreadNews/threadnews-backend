# %%
import urllib
import text2emotion
from bs4 import BeautifulSoup
url = "https://www.cnn.com/2021/02/13/politics/trump-legal-problems-post-impeachment/index.html"
html = urllib.request.urlopen(url).read()
soup = BeautifulSoup(html)

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()    # rip it out

# get text
text = soup.get_text()

# break into lines and remove leading and trailing space on each
lines = (line.strip() for line in text.splitlines())
# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk)

text = text.split(" ")
print(type(text))
common_word = {""}
n = []
for word in text:
    if (word.strip().islower()):
        n.append(word)
from nltk import FreqDist


print(n)
text = ''.join(str(e+' ') for e in n)

print(text.encode('utf-8'))
freq_dist_pos = FreqDist(n)
print(freq_dist_pos.most_common(10))
# Out:
# <class 'list'>
# ['heaping', 'list', 'of', 'legal', 'problems', 'post-impeachment\n-', 'and', 'for', 'is', 'heaping', 'list', 'of', 'legal', 'problems', 'and', 'sources', 'telling', 'me', "'this", 'is', 'not', 'sources', 'telling', 'me', "'this", 'is', 'not', "didn't", 'need', 'more', 'witnesses,', 'we', 'needed', 'more', 'senators', 'with', 'acquits', 'of', 'inciting', 'the', 'final', 'chapter', "hasn't", 'been', 'sound', 'off', 'on', 'politics:', 'scary,', 'waste', 'of', 'deputy', 'press', 'secretary', 'resigns', 'manager', 'reacts', 'to', 'laughs', 'during', "lawyer's", 'video', 'shows', 'how', 'close', 'rioters', 'got', 'to', 'attorneys', 'present', 'their', 'case', 'in', 'under', 'accused', 'of', 'covering', 'up', 'nursing', 'home', 'details', 'emerge', 'in', 'call', 'with', 'on', 'breaks', 'with', "shouldn't", 'have', 'followed', 'calls', "senators'", 'meeting', 'with', 'defense', 'team', 'of', 'senators', 'not', 'up', 'for', 'reelection', 'in', 'leader', 'waited', 'for', 'direction', 'averting', 'a', 'conviction', 'in', 'his', 'second', 'impeachment', 'trial,', 'former', 'faces', 'significant', 'new', 'legal', 'threats', 'as', 'prosecutors', 'in', 'have', 'joined', 'those', 'in', 'to', 'conduct', 'criminal', 'investigations', 'into', 'his', 'the', 'nation', 'watched', 'harrowing', 'videos', 'from', 'of', 'supporters', 'storming', 'the', 'during', 'the', 'impeachment', 'trial', 'this', 'week,', 'officials', 'announced', 'they', 'have', 'opened', 'investigations', 'into', 'efforts', 'to', 'overturn', 'the', "state's", 'election', 'results,', 'including', 'by', 'pressuring', 'officials', 'to', '"find"', 'votes', 'to', 'swing', 'the', 'outcome', 'in', 'his', 'favor.', 'new', 'investigations', 'add', 'to', 'a', 'heaping', 'list', 'of', 'legal', 'issues', 'facing', 'the', 'former', 'that', 'could', 'threaten', 'his', 'finances', 'and', 'possibly', 'his', 'of', 'office', 'and', 'without', 'the', 'protections', 'that', 'the', 'presidency', 'afforded', 'him,', 'is', 'now', 'facing', 'multiple', 'criminal', 'investigations,', 'civil', 'state', 'inquiries', 'and', 'defamation', 'lawsuits', 'by', 'two', 'women', 'accusing', 'him', 'of', 'sexual', 'pressure', 'comes', 'as', 'weighs', 'his', 'future', 'in', 'politics', 'and', 'in', 'business', 'with', 'the', 'which', 'has', 'already', 'been', 'impacted', 'by', 'the', 'pandemic,', 'also', 'losing', 'corporate', 'partnerships', 'following', 'speech', 'whipping', 'up', 'the', 'the', 'three', 'weeks', 'since', 'left', 'the', 'the', 'multiple', 'legal', 'threats', 'he', 'faces', 'have', 'increased', 'and', 'become', 'more', 'election', 'results', 'officials', 'announced', 'that', 'the', 'former', 'faces', 'two', 'new', 'investigations', 'over', 'calls', 'he', 'made', 'to', 'election', 'officials', 'in', 'an', 'attempt', 'to', 'overturn', 'the', "state's", 'election', 'source', 'familiar', 'with', 'the', 'secretary', 'of', "state's", 'investigation', 'confirmed', 'they', 'are', 'investigating', 'two', 'calls,', 'including', 'one', 'made', 'to', 'of', 'the', 'call,', 'audio', 'of', 'which', 'was', 'obtained', 'by', 'is', 'heard', 'pushing', 'to', '"find"', 'votes', 'to', 'overturn', 'the', 'election', 'results', 'after', 'his', 'loss', 'to', 'is', 'not', 'an', 'easy', 'case,', 'but', "it's", 'not', 'one', 'that', 'you', 'should', 'walk', 'away', 'from', 'investigating,"', 'said', 'a', 'former', 'federal', 'prosecutor', 'in', 'and', 'will', 'be', 'tough', 'to', 'show', 'that', 'he', 'had', 'intent', 'to', 'solicit', 'to', 'commit', 'election', 'fraud', 'but', 'he', 'may', 'senior', 'adviser,', 'said', 'in', 'a', 'statement', 'to', 'that', 'there', 'was', 'nothing', '"improper', 'or', 'untoward"', 'about', 'the', 'scheduled', 'call', 'between', 'and', "didn't", 'want', 'to', 'receive', 'calls', 'about', 'the', 'election,', 'he', "shouldn't", 'have', 'run', 'for', 'secretary', 'of', 'state,"', 'said', 'in', 'the', 'investigation', 'also', 'involves', 'a', 'call', 'made', 'in', 'to', 'a', 'election', 'investiga ...
# b'heaping list of legal problems post-impeachment\n- and for is heaping list of legal problems and sources telling me \'this is not sources telling me \'this is not didn\'t need more witnesses, we needed more senators with acquits of inciting the final chapter hasn\'t been sound off on politics: scary, waste of deputy press secretary resigns manager reacts to laughs during lawyer\'s video shows how close rioters got to attorneys present their case in under accused of covering up nursing home details emerge in call with on breaks with shouldn\'t have followed calls senators\' meeting with defense team of senators not up for reelection in leader waited for direction averting a conviction in his second impeachment trial, former faces significant new legal threats as prosecutors in have joined those in to conduct criminal investigations into his the nation watched harrowing videos from of supporters storming the during the impeachment trial this week, officials announced they have opened investigations into efforts to overturn the state\'s election results, including by pressuring officials to "find" votes to swing the outcome in his favor. new investigations add to a heaping list of legal issues facing the former that could threaten his finances and possibly his of office and without the protections that the presidency afforded him, is now facing multiple criminal investigations, civil state inquiries and defamation lawsuits by two women accusing him of sexual pressure comes as weighs his future in politics and in business with the which has already been impacted by the pandemic, also losing corporate partnerships following speech whipping up the the three weeks since left the the multiple legal threats he faces have increased and become more election results officials announced that the former faces two new investigations over calls he made to election officials in an attempt to overturn the state\'s election source familiar with the secretary of state\'s investigation confirmed they are investigating two calls, including one made to of the call, audio of which was obtained by is heard pushing to "find" votes to overturn the election results after his loss to is not an easy case, but it\'s not one that you should walk away from investigating," said a former federal prosecutor in and will be tough to show that he had intent to solicit to commit election fraud but he may senior adviser, said in a statement to that there was nothing "improper or untoward" about the scheduled call between and didn\'t want to receive calls about the election, he shouldn\'t have run for secretary of state," said in the investigation also involves a call made in to a election investigator in the state secretary of state\'s office who was leading a probe into allegations of ballot fraud in is heard asking the investigator to "find the fraud," saying the official would be a "national second investigation is being conducted by the office, which announced that it has also opened a criminal investigation into for his "attempts to influence the administration of the general that violates the law will be prosecuted, no matter what their social stature is, no matter what their economics are, no matter what their race is or their gender. not going to treat anyone differently," told affiliate in an interview earlier this week. earliest a grand jury is expected to convene is in and the district attorney\'s office can request grand jury subpoenas as necessary at that time. believe laws were broken because think it was a clear effort by at the time a of the who think at the time also wielded a certain amount of power to influence the secretary of state to do something wrong," said a former for the of during the administration. think that\'s what the statute says, and if those things happened, that\'s a violation of law," he dealings in also faces a criminal investigation in where the office is looking into whether the violated state laws, such as insurance fraud, t ...
# [('the', 98), ('to', 49), ('in', 45), ('of', 43), ('a', 33), ('and', 28), ('is', 27), ('that', 22), ('for', 14), ('by', 14)]

# %%
file = open("common_words.txt")
#print(file.read())
n2=[]
commons = file.read().replace('\t',' ').replace('\n',' ').split(' ')
for word in n:
    if(word not in commons):
        n2.append(word)
print(text2emotion.get_emotion(text))
# Out:
# {'Happy': 0.06, 'Angry': 0.07, 'Surprise': 0.28, 'Sad': 0.22, 'Fear': 0.37}

# %%
print(n2)
# Out:
# ['heaping', 'list', 'legal', 'problems', 'post-impeachment\n-', 'heaping', 'list', 'legal', 'problems', 'sources', 'telling', 'me', "'this", 'sources', 'telling', 'me', "'this", "didn't", 'need', 'more', 'witnesses,', 'needed', 'more', 'senators', 'acquits', 'inciting', 'final', 'chapter', "hasn't", 'been', 'sound', 'off', 'politics:', 'scary,', 'waste', 'deputy', 'press', 'secretary', 'resigns', 'manager', 'reacts', 'laughs', 'during', "lawyer's", 'video', 'shows', 'close', 'rioters', 'got', 'attorneys', 'present', 'case', 'under', 'accused', 'covering', 'up', 'nursing', 'home', 'details', 'emerge', 'call', 'breaks', "shouldn't", 'followed', 'calls', "senators'", 'meeting', 'defense', 'team', 'senators', 'up', 'reelection', 'leader', 'waited', 'direction', 'averting', 'conviction', 'second', 'impeachment', 'trial,', 'former', 'faces', 'significant', 'new', 'legal', 'threats', 'prosecutors', 'joined', 'those', 'conduct', 'criminal', 'investigations', 'into', 'nation', 'watched', 'harrowing', 'videos', 'supporters', 'storming', 'during', 'impeachment', 'trial', 'week,', 'officials', 'announced', 'opened', 'investigations', 'into', 'efforts', 'overturn', "state's", 'election', 'results,', 'including', 'pressuring', 'officials', '"find"', 'votes', 'swing', 'outcome', 'favor.', 'new', 'investigations', 'add', 'heaping', 'list', 'legal', 'issues', 'facing', 'former', 'could', 'threaten', 'finances', 'possibly', 'office', 'without', 'protections', 'presidency', 'afforded', 'him,', 'now', 'facing', 'multiple', 'criminal', 'investigations,', 'civil', 'state', 'inquiries', 'defamation', 'lawsuits', 'two', 'women', 'accusing', 'him', 'sexual', 'pressure', 'comes', 'weighs', 'future', 'politics', 'business', 'has', 'already', 'been', 'impacted', 'pandemic,', 'also', 'losing', 'corporate', 'partnerships', 'following', 'speech', 'whipping', 'up', 'three', 'weeks', 'since', 'left', 'multiple', 'legal', 'threats', 'faces', 'increased', 'become', 'more', 'election', 'results', 'officials', 'announced', 'former', 'faces', 'two', 'new', 'investigations', 'over', 'calls', 'made', 'election', 'officials', 'attempt', 'overturn', "state's", 'election', 'source', 'familiar', 'secretary', "state's", 'investigation', 'confirmed', 'investigating', 'two', 'calls,', 'including', 'one', 'made', 'call,', 'audio', 'obtained', 'heard', 'pushing', '"find"', 'votes', 'overturn', 'election', 'results', 'after', 'loss', 'easy', 'case,', "it's", 'one', 'should', 'walk', 'away', 'investigating,"', 'former', 'federal', 'prosecutor', 'will', 'tough', 'show', 'intent', 'solicit', 'commit', 'election', 'fraud', 'may', 'senior', 'adviser,', 'statement', 'nothing', '"improper', 'untoward"', 'about', 'scheduled', 'call', 'between', "didn't", 'want', 'receive', 'calls', 'about', 'election,', "shouldn't", 'run', 'secretary', 'state,"', 'investigation', 'also', 'involves', 'call', 'made', 'election', 'investigator', 'state', 'secretary', "state's", 'office', 'who', 'leading', 'probe', 'into', 'allegations', 'ballot', 'fraud', 'heard', 'asking', 'investigator', '"find', 'fraud,"', 'saying', 'official', 'would', '"national', 'second', 'investigation', 'being', 'conducted', 'office,', 'announced', 'has', 'also', 'opened', 'criminal', 'investigation', 'into', '"attempts', 'influence', 'administration', 'general', 'violates', 'law', 'will', 'prosecuted,', 'no', 'matter', 'social', 'stature', 'is,', 'no', 'matter', 'economics', 'are,', 'no', 'matter', 'race', 'gender.', 'going', 'treat', 'anyone', 'differently,"', 'told', 'affiliate', 'interview', 'earlier', 'week.', 'earliest', 'grand', 'jury', 'expected', 'convene', 'district', "attorney's", 'office', 'request', 'grand', 'jury', 'subpoenas', 'necessary', 'time.', 'believe', 'laws', 'broken', 'because', 'think', 'clear', 'effort', 'time', 'who', 'think', 'time', 'also', 'wielded', 'certain', 'amount', 'power', 'influence', 'secretary', 'state', 'something', 'wrong,"', 'former', 'during', 'administration.', 'think', "that's", 'st ...
